# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
# %matplotlib inline

from sklearn.datasets import make_classification

X, y = make_classification(n_samples=1000, n_features=4, 
                            n_classes=2, random_state=42)

X = pd.DataFrame(X, columns=['Feature1','Feature2','Feature3','Feature4'])
y = pd.Series(y)

# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=101)

# -------- Decision Tree --------
dtree = DecisionTreeClassifier()
dtree.fit(X_train, y_train)
dt_pred = dtree.predict(X_test)

print("===== Decision Tree =====")
print(confusion_matrix(y_test, dt_pred))
print(classification_report(y_test, dt_pred))

# -------- Random Forest --------
rforest = RandomForestClassifier(n_estimators=101, random_state=42)
rforest.fit(X_train, y_train)
rf_pred = rforest.predict(X_test)

print("===== Random Forest =====")
print(confusion_matrix(y_test, rf_pred))
print(classification_report(y_test, rf_pred))

# -------- Comparison --------
dt_acc = round(classification_report(y_test, dt_pred, output_dict=True)['accuracy'], 2)
rf_acc = round(classification_report(y_test, rf_pred, output_dict=True)['accuracy'], 2)

print(f"\nDecision Tree Accuracy : {dt_acc}")
print(f"Random Forest Accuracy : {rf_acc}")
print(f"Random Forest better by: {round(rf_acc - dt_acc, 2)}")
# Out:
# ===== Decision Tree =====
# [[131  19]
#  [ 20 130]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87       150
#            1       0.87      0.87      0.87       150
#
#     accuracy                           0.87       300
#    macro avg       0.87      0.87      0.87       300
# weighted avg       0.87      0.87      0.87       300
#
# ===== Random Forest =====
# [[139  11]
#  [ 14 136]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       150
#            1       0.93      0.91      0.92       150
#
#     accuracy                           0.92       300
#    macro avg       0.92      0.92      0.92       300
# weighted avg       0.92      0.92      0.92       300
#
#
# Decision Tree Accuracy : 0.87
# Random Forest Accuracy : 0.92
# Random Forest better by: 0.05
